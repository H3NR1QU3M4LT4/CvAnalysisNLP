# %% [markdown]
# # Env

# %%
# !pip install tensorboard
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %load_ext tensorboard

# %% [markdown]
# # Colors

# %%
# XML
# #ff2d00
# LMv2
# #15f900
# LMv3
# #00a1ff

# %% [markdown]
# # Sections

# %%
# %tensorboard --logdir "/content/drive/MyDrive/tensorboard/sections/runs"

# %% [markdown]
# # WE lables

# %%
# %tensorboard --logdir "/content/drive/MyDrive/tensorboard/we/runs"
# xml laranja
# v2 azul
# v3 vermelho

# %% [markdown]
# # EDUC Labels

# %%
# %tensorboard --logdir "/content/drive/MyDrive/tensorboard/educ/runs"

# %% [markdown]
# # Blocks

# %%
# %tensorboard --logdir "/content/drive/MyDrive/tensorboard/blocks/runs"
